# %%
import matplotlib.pyplot as plt
cfg = toml.load('../config.toml')
from matplotlib import pyplot as plt

targets = pd.read_csv('../results/targets/targets.csv')
dataset_lengh_sec = targets.shape[0]
ts = np.arange(0, dataset_lengh_sec + cfg['dt'], cfg['dt'])
print(ts)
print(len(ts))

predictions = pd.read_csv('../results/predictions/lstm1/0.013_lstm1_hid1024_epochs500_batch256_08.08_074718.csv',
                          names=["x", "y", "z", "qx", "qy", "qz", "qw"])
# Out:
# [0.0000000e+00 5.0000000e-03 1.0000000e-02 ... 2.3807990e+04 2.3807995e+04
#  2.3808000e+04]
# 4761601

# %%
compare1 = 'x'
comp1 = plt.figure()
f1_1 = plt.plot(targets.loc[:len(ts)-1, compare1],label='target_X', linestyle='--')
f1_2 = plt.plot(predictions.loc[:len(ts)-1, compare1],label='pred_X', linestyle=':')
comp1.set_figwidth(20)
comp1.set_figheight(5)
plt.legend()
f1 = plt.show()

# %%
compare2 = 'y'
comp2 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare2],label='target_Y', linestyle='--')
plt.plot(predictions.loc[:len(ts)-1, compare2],label='pred_Y', linestyle=':')
comp2.set_figwidth(20)
comp2.set_figheight(5)
plt.legend()
plt.show()

# %%
compare3 = 'z'
comp3 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare3], label='target_Z', linestyle='--')
plt.plot(predictions.loc[:len(ts)-1, compare3], label='pred_Z', linestyle=':')
comp3.set_figwidth(20)
comp3.set_figheight(5)
plt.show()

# %%
compare4 = 'qx'
comp4 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare4], label='target_QX', linestyle='--')
plt.plot(predictions.loc[:len(ts)-1, compare4], label='pred_QX', linestyle=':')
comp4.set_figwidth(20)
comp4.set_figheight(5)
plt.legend()
plt.show()

# %%
compare5 = 'qy'
comp5 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare5], label='target_QY', linestyle='--')
plt.plot(predictions.loc[:len(ts)-1, compare5], label='pred_QY', linestyle=':')
comp5.set_figwidth(20)
comp5.set_figheight(5)
plt.legend()
plt.show()

# %%
compare6 = 'qz'
comp6 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare6], label='target_QZ', linestyle='--')
plt.plot(predictions.loc[:len(ts)-1, compare6], label='pred_QZ', linestyle=':')
comp6.set_figwidth(20)
comp6.set_figheight(5)
plt.legend()
plt.show()

# %%
compare7 = 'qw'
comp7 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare7], label='target_QW', linestyle='--')
plt.plot(predictions.loc[:len(ts)-1, compare7], label='pred_QW', linestyle=':')
comp7.set_figwidth(20)
comp7.set_figheight(5)
plt.legend()
plt.show()

# %%
TODO
------ 1. plot with best values
2. divide position and rotation
3. min-max position
4. repait lstm-fcn!
