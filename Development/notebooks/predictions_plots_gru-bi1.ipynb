# %%
import toml
import matplotlib.pyplot as plt
cfg = toml.load('../UserPrediction6DOF/tools/config.toml')
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

dest = '../results/plotter/pred_vs_real/'
model = 'gru-bi1'

targets = pd.read_csv('../results/targets/targets.csv')
base = pd.read_csv('../results/predictions/baseline/baseline_predictions.csv', names=["x", "y", "z", "qx", "qy", "qz", "qw"])

dataset_lengh_sec = targets.shape[0]
ts = np.arange(0, dataset_lengh_sec + cfg['dt'], cfg['dt'])

predictions = pd.read_csv('../results/predictions/gru-bi1/MAE_pos_0.0604_hid256_batch128_epochs500_LR0.0001_every50_epochs_with_WD9e-13_for_LAT100_29.08_151750.csv',
                          names=["x", "y", "z", "qx", "qy", "qz", "qw"])

# %%
compare1 = 'x'
comp1 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare1],label='target_X')
plt.plot(predictions.loc[:len(ts)-1, compare1],label='pred_X')
plt.plot(base.loc[:len(ts)-1, compare1],label='base_X')
comp1.set_figwidth(20)
comp1.set_figheight(10)
plt.legend()
plt.show()
dest1 = os.path.join(dest, f"{model}-{compare1}.pdf")
comp1.savefig(dest1)

# %%
compare2 = 'y'
comp2 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare2],label='target_Y')
plt.plot(predictions.loc[:len(ts)-1, compare2],label='pred_Y')
plt.plot(base.loc[:len(ts)-1, compare2],label='base_Y')
comp2.set_figwidth(20)
comp2.set_figheight(10)
plt.legend()
plt.show()
dest2 = os.path.join(dest, f"{model}-{compare2}.pdf")
comp2.savefig(dest2)

# %%
compare3 = 'z'
comp3 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare3],label='target_Z')
plt.plot(predictions.loc[:len(ts)-1, compare3],label='pred_Z')
plt.plot(base.loc[:len(ts)-1, compare3],label='base_Z')
comp3.set_figwidth(20)
comp3.set_figheight(10)
plt.show()
dest3 = os.path.join(dest, f"{model}-{compare3}.pdf")
comp3.savefig(dest3)

# %%
compare4 = 'qx'
comp4 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare4],label='target_QX')
plt.plot(predictions.loc[:len(ts)-1, compare4],label='pred_QX')
plt.plot(base.loc[:len(ts)-1, compare4],label='base_QX')
comp4.set_figwidth(20)
comp4.set_figheight(10)
plt.legend()
plt.show()
dest4 = os.path.join(dest, f"{model}-{compare4}.pdf")
comp4.savefig(dest4)

# %%
compare5 = 'qy'
comp5 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare5],label='target_QY')
plt.plot(predictions.loc[:len(ts)-1, compare5],label='pred_QY')
plt.plot(base.loc[:len(ts)-1, compare5],label='base_QY')
comp5.set_figwidth(20)
comp5.set_figheight(10)
plt.legend()
plt.show()
dest5 = os.path.join(dest, f"{model}-{compare5}.pdf")
comp5.savefig(dest5)

# %%
compare6 = 'qz'
comp6 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare6],label='target_QZ')
plt.plot(predictions.loc[:len(ts)-1, compare6],label='pred_QZ')
plt.plot(base.loc[:len(ts)-1, compare6],label='base_QZ')
comp6.set_figwidth(20)
comp6.set_figheight(10)
plt.legend()
plt.show()
dest6 = os.path.join(dest, f"{model}-{compare6}.pdf")
comp6.savefig(dest6)

# %%
compare7 = 'qw'
comp7 = plt.figure()
plt.plot(targets.loc[:len(ts)-1, compare7],label='target_QW')
plt.plot(predictions.loc[:len(ts)-1, compare7],label='pred_QW')
plt.plot(base.loc[:len(ts)-1, compare7],label='base_QW')
comp7.set_figwidth(20)
comp7.set_figheight(10)
plt.legend()
plt.show()
dest7 = os.path.join(dest, f"{model}-{compare7}.pdf")
comp7.savefig(dest7)

# %%
compare20 = 'x'
comp20 = plt.figure()
plt.plot(targets.loc[0:1000, compare20],label='target_X')
plt.plot(predictions.loc[0:1000, compare20],label='pred_X')
plt.plot(base.loc[0:1000, compare20],label='base_X')
comp20.set_figwidth(20)
comp20.set_figheight(10)
plt.legend()
plt.show()
dest20 = os.path.join(dest, f"{model}-{compare20}_base_pred_zoomed.pdf")
comp20.savefig(dest20)

# %%
compare20 = 'y'
comp20 = plt.figure()
plt.plot(targets.loc[0:2000, compare20],label='target_Y')
plt.plot(predictions.loc[0:2000, compare20],label='pred_Y')
plt.plot(base.loc[0:2000, compare20],label='base_Y')
comp20.set_figwidth(20)
comp20.set_figheight(10)
plt.legend()
plt.show()
dest20 = os.path.join(dest, f"{model}-{compare20}_base_pred_zoomed.pdf")
comp20.savefig(dest20)

# %%
compare20 = 'z'
comp20 = plt.figure()
plt.plot(targets.loc[0:1000, compare20],label='target_Z')
plt.plot(predictions.loc[0:1000, compare20],label='pred_Z')
plt.plot(base.loc[0:1000, compare20],label='base_Z')
comp20.set_figwidth(20)
comp20.set_figheight(10)
plt.legend()
plt.show()
dest20 = os.path.join(dest, f"{model}-{compare20}_base_pred_zoomed.pdf")
comp20.savefig(dest20)

# %%
compare20 = 'qx'
comp20 = plt.figure()
plt.plot(targets.loc[0:2000, compare20],label='target_QX')
plt.plot(predictions.loc[0:2000, compare20],label='pred_QX')
plt.plot(base.loc[0:2000, compare20],label='base_QX')
comp20.set_figwidth(20)
comp20.set_figheight(10)
plt.legend()
plt.show()
dest20 = os.path.join(dest, f"{model}-{compare20}_base_pred_zoomed.pdf")
comp20.savefig(dest20)

# %%
compare20 = 'qy'
comp20 = plt.figure()
plt.plot(targets.loc[0:2000, compare20],label='target_QY')
plt.plot(predictions.loc[0:2000, compare20],label='pred_QY')
plt.plot(base.loc[0:2000, compare20],label='base_QY')
comp20.set_figwidth(20)
comp20.set_figheight(10)
plt.legend()
plt.show()
dest20 = os.path.join(dest, f"{model}-{compare20}_base_pred_zoomed.pdf")
comp20.savefig(dest20)

# %%
compare20 = 'qz'
comp20 = plt.figure()
plt.plot(targets.loc[0:2000, compare20],label='target_QZ')
plt.plot(predictions.loc[0:2000, compare20],label='pred_QZ')
plt.plot(base.loc[0:2000, compare20],label='base_QZ')
comp20.set_figwidth(20)
comp20.set_figheight(10)
plt.legend()
plt.show()
dest20 = os.path.join(dest, f"{model}-{compare20}_base_pred_zoomed.pdf")
comp20.savefig(dest20)

# %%
compare20 = 'qw'
comp20 = plt.figure()
plt.plot(targets.loc[0:2000, compare20],label='target_QW')
plt.plot(predictions.loc[0:2000, compare20],label='pred_QW')
plt.plot(base.loc[0:2000, compare20],label='base_QW')
comp20.set_figwidth(20)
comp20.set_figheight(10)
plt.legend()
plt.show()
dest20 = os.path.join(dest, f"{model}-{compare20}_base_pred_zoomed.pdf")
comp20.savefig(dest20)

# %%
losses = pd.read_csv('../results/losses/gru1/MAE_pos_0.0099_hid1024_batch512_epochs500_LR0.0001_every50_epochs_with_WD2e-12_for_LAT100_15.08_073303.csv')
epochs = 500
los_fig = plt.figure()
plt.plot(losses.loc[0:epochs-1, 'Train_loss'], label='Train_loss')
plt.plot(losses.loc[0:epochs-1, 'Val_loss'], label='Val_loss')
los_fig.set_figwidth(20)
los_fig.set_figheight(10)
plt.legend()
plt.show()
los_fig.savefig('../results/losses/gru1_MAE_pos_0.0099_hid1024_batch512_epochs500_LR0.0001_every50_epochs_with_WD2e-12_for_LAT100_15.08_073303.pdf')

# %%
los_fig_z = plt.figure()
plt.plot(losses.loc[0:100, 'Train_loss'], label='Train_loss')
plt.plot(losses.loc[0:100, 'Val_loss'], label='Val_loss')
los_fig_z.set_figwidth(20)
los_fig_z.set_figheight(10)
plt.legend()
plt.show()
los_fig_z.savefig('../results/losses/gru1_MAE_pos_0.0099_ZOOM_hid1024_batch512_epochs500_LR0.0001_every50_epochs_with_WD2e-12_for_LAT100_15.08_073303.pdf')

# %%
kalman = pd.read_csv('../results/predictions/kalman/kalman_predictions.csv', names=["x", "y", "z", "qx", "qy", "qz", "qw"]) 
compare29 = 'qw'
comp29 = plt.figure()
plt.plot(targets.loc[0:2000, compare29],label='target_QW')
plt.plot(predictions.loc[0:2000, compare29],label='pred_QW')
plt.plot(base.loc[0:2000, compare29],label='base_QW')
plt.plot(kalman.loc[0:2000, compare29],label='kalman_QW')
comp29.set_figwidth(20)
comp29.set_figheight(10)
plt.legend()
plt.show()
dest29 = os.path.join(dest, f"kalman-{compare29}_base_pred_zoomed.pdf")
comp29.savefig(dest29)

# %%
compare29 = 'qy'
comp29 = plt.figure()
plt.plot(targets.loc[0:2000, compare29],label='target_QY')
plt.plot(predictions.loc[0:2000, compare29],label='pred_QY')
plt.plot(base.loc[0:2000, compare29],label='base_QY')
plt.plot(kalman.loc[0:2000, compare29],label='kalman_QY')
comp29.set_figwidth(20)
comp29.set_figheight(10)
plt.legend()
plt.show()
dest29 = os.path.join(dest, f"kalman-{compare29}_base_pred_zoomed.pdf")
comp29.savefig(dest29)

# %%
compare29 = 'qx'
comp29 = plt.figure()
plt.plot(targets.loc[0:2000, compare29],label='target_QX')
plt.plot(predictions.loc[0:2000, compare29],label='pred_QX')
plt.plot(base.loc[0:2000, compare29],label='base_QX')
plt.plot(kalman.loc[0:2000, compare29],label='kalman_QX')
comp29.set_figwidth(20)
comp29.set_figheight(10)
plt.legend()
plt.show()
dest29 = os.path.join(dest, f"kalman-{compare29}_base_pred_zoomed.pdf")
comp29.savefig(dest29)

# %%
compare29 = 'qz'
comp29 = plt.figure()
plt.plot(targets.loc[0:2000, compare29],label='target_QZ')
plt.plot(predictions.loc[0:2000, compare29],label='pred_QZ')
plt.plot(base.loc[0:2000, compare29],label='base_QZ')
plt.plot(kalman.loc[0:2000, compare29],label='kalman_QZ')
comp29.set_figwidth(20)
comp29.set_figheight(10)
plt.legend()
plt.show()
dest29 = os.path.join(dest, f"kalman-{compare29}_base_pred_zoomed.pdf")
comp29.savefig(dest29)

# %%
compare29 = 'x'
comp29 = plt.figure()
plt.plot(targets.loc[0:2000, compare29],label='target_X')
plt.plot(predictions.loc[0:2000, compare29],label='pred_X')
plt.plot(base.loc[0:2000, compare29],label='base_X')
plt.plot(kalman.loc[0:2000, compare29],label='kalman_X')
comp29.set_figwidth(20)
comp29.set_figheight(10)
plt.legend()
plt.show()
dest29 = os.path.join(dest, f"kalman-{compare29}_base_pred_zoomed.pdf")
comp29.savefig(dest29)

# %%
compare29 = 'y'
comp29 = plt.figure()
plt.plot(targets.loc[0:2000, compare29],label='target_Y')
plt.plot(predictions.loc[0:2000, compare29],label='pred_Y')
plt.plot(base.loc[0:2000, compare29],label='base_Y')
plt.plot(kalman.loc[0:2000, compare29],label='kalman_Y')
comp29.set_figwidth(20)
comp29.set_figheight(10)
plt.legend()
plt.show()
dest29 = os.path.join(dest, f"kalman-{compare29}_base_pred_zoomed.pdf")
comp29.savefig(dest29)

# %%
compare29 = 'z'
comp29 = plt.figure()
plt.plot(targets.loc[0:2000, compare29],label='target_Z')
plt.plot(predictions.loc[0:2000, compare29],label='pred_Z')
plt.plot(base.loc[0:2000, compare29],label='base_Z')
plt.plot(kalman.loc[0:2000, compare29],label='kalman_Z')
comp29.set_figwidth(20)
comp29.set_figheight(10)
plt.legend()
plt.show()
dest29 = os.path.join(dest, f"kalman-{compare29}_base_pred_zoomed.pdf")
comp29.savefig(dest29)
